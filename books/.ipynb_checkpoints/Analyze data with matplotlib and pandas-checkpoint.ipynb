# %%
import pandas as pd

# %%
df = pd.read_csv('red30.csv')

# %%
df.head(20)
# Out:
#     OrderNum  OrderType CustomerType                CustName       CustState  \
# 0    1100934  Wholesale     Business        Gusikowski Group  North Carolina
# 1    1100935     Retail   Individual       Spencer Educators        Delaware
# 2    1100936  Wholesale     Business           Schinner Inc.         Florida
# 3    1100937     Retail   Individual            Saxon Laviss        Virginia
# 4    1100938     Retail     Business  Wilderman Technologies           Texas
# 5    1100939  Wholesale     Business           Turcotte Corp        New York
# 6    1100940     Retail   Individual        Kovacek Bernhard           Texas
# 7    1100941     Retail   Individual          Antonina Noton        Missouri
# 8    1100942     Retail   Individual      Frederik Pantecost       Louisiana
# 9    1100943  Wholesale     Business      Hettinger and Sons   West Virginia
# 10   1100944     Retail   Individual       Phylis Barrabeale           Texas
# 11   1100945  Wholesale     Business             Marvin Inc.          Kansas
# 12   1100946  Wholesale     Business              Jacobi LLC         Arizona
# 13   1100947     Retail   Individual             Elton Sexon        Colorado
# 14   1100948     Retail   Individual               Ewan Ladd            Ohio
# 15   1100949     Retail   Individual      Justine Trengrouse         Florida
# 16   1100950     Retail   Individual          Cristian Iston        New York
# 17   1100951  Wholesale     Business           Treutel Group        New York
# 18   1100952  Wholesale     Business        Oberbrunner Inc.         Alabama
# 19   1100953  Wholesale     Business       Clever Industries            Utah
#
#        ProdCategory ProdNumber                               ProdName  \
# 0        Blueprints      BP102                Bsquare Robot Blueprint
# 1        Drone Kits      DK204                               BYOD-300
# 2   Training Videos      TV801                        Aerial Security
# 3        Robot Kits      RK602                              BYOR-1000
# 4            eBooks      EB502              Building Your First Robot
# 5            Drones      DS302                           DC-304 Drone
# 6   Training Videos      TV803                        Cloud Computing
# 7            Drones      DS306                           DX-145 Drone
# 8            eBooks      EB507              Drone Building Essentials
# 9        Blueprints      BP104                    Cat Robot Blueprint
# 10  Training Videos      TV812             Understanding Raspberry PI
# 11  Training Videos      TV802                       AI for Educators
# 12           eBooks      EB509                             GPS Drones
# 13  Training Videos      TV811        Understanding Drone Regulations
# 14  Training Videos      TV810               Understanding Automation
# 15           eBooks      EB507              Drone Building Essentials
# 16       Robot Kits      RK603                              BYOR-1500
# 17       Drone Kits      DK209                               BYOD-550
# 18           eBooks      EB521  Understanding Artificial Intelligence
# 19       Drone Kits      DK209                               BYOD-550
#
#     Quantity     Price Discount   OrderTotal
# 0         10    $8.99    $1.80       $88.10
# 1          2   $89.00         0     $178.00
# 2         10   $36.99    $7.40      $362.50
# 3          1  $189.00         0     $189.00
# 4          4   $24.95         0      $99.80
# 5         79  $395.00   $79.00   $31,126.00
# 6          1   $29.99         0      $29.99
# 7          2  $250.00         0     $500.00
# 8          1   $13.99         0      $13.99
# 9          6    $4.99    $1.00       $28.94
# 10         1   $28.99         0      $28.99
# 11         5   $49.95    $9.99      $239.76
# 12         7   $19.99    $4.00      $135.93
# 13         1   $27.50         0      $27.50
# 14         1   $44.95         0      $44.95
# 15         1   $13.99         0      $13.99
# 16         1  $189.00         0     $189.00
# 17        27  $179.00   $35.80    $4,797.20
# 18         5   $19.50    $3.90       $93.60
# 19         5  $179.00   $35.80      $859.20

# %%
df.tail()
# Out:
#       OrderNum  OrderType CustomerType          CustName       CustState  \
# 4971   1105905  Wholesale     Business     Rau-Dickinson        Kentucky
# 4972   1105906  Wholesale     Business  Reichel and Sons        Oklahoma
# 4973   1105907  Wholesale     Business         Wolff LLC  South Carolina
# 4974   1105908     Retail     Business      McClure Inc.            Utah
# 4975   1105909     Retail   Individual    Gussi Strodder        New York
#
#      ProdCategory ProdNumber                   ProdName  Quantity     Price  \
# 4971       eBooks      EB503    Building Your Own Drone         5   $24.99
# 4972       eBooks      EB502  Building Your First Robot         5   $24.95
# 4973   Blueprints      BP104        Cat Robot Blueprint        10    $4.99
# 4974   Drone Kits      DK209                   BYOD-550        64  $179.00
# 4975   Drone Kits      DK204                   BYOD-300         1   $89.00
#
#      Discount   OrderTotal
# 4971   $5.00      $119.95
# 4972   $4.99      $119.76
# 4973   $1.00       $48.90
# 4974        0  $11,456.00
# 4975        0      $89.00

# %%
df.describe()
# Out:
#            OrderNum     Quantity
# count  4.976000e+03  4976.000000
# mean   1.103422e+06    11.107516
# std    1.436592e+03    20.367634
# min    1.100934e+06     1.000000
# 25%    1.102178e+06     1.000000
# 50%    1.103422e+06     5.000000
# 75%    1.104665e+06    10.000000
# max    1.105909e+06   109.000000

# %%
df['ProdCategory'].value_counts
# Out:
# ProdCategory
# eBooks             1296
# Training Videos     992
# Blueprints          912
# Drone Kits          552
# Robot Kits          480
# Drones              408
# Robots              336
# Name: count, dtype: int64

# %%
df['OrderType'].value_counts()
# Out:
# OrderType
# Wholesale    2833
# Retail       2143
# Name: count, dtype: int64

# %%
df['OrderTotal'].describe()
# Out:
# count        4976
# unique       1215
# top       $12.00
# freq           90
# Name: OrderTotal, dtype: object

# %%
df['OrderTotal'].value_counts()
# Out:
# OrderTotal
# $12.00         90
# $8.99          90
# $49.00         87
# $4.99          86
# $23.99         84
#                ..
# $40,612.20      1
# $1,385.01       1
# $672.00         1
# $1,794.28       1
# $11,456.00      1
# Name: count, Length: 1215, dtype: int64

# %%
import matplotlib

# %%
df['Quantity'].hist()
# Out:
# <Axes: >

# %%
 df['ProdCategory'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='ProdCategory'>
